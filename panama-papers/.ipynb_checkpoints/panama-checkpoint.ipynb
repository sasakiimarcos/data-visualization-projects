# %%
import pandas as pd
import numpy as np
import geopandas as gpd
from matplotlib.lines import Line2D

# %%
edges = pd.read_csv('./data/panama_papers.edges.csv', low_memory=False)
address = pd.read_csv('./data/panama_papers.nodes.address.csv')
entity = pd.read_csv('./data/panama_papers.nodes.entity.csv', low_memory=False)
intermediary = pd.read_csv('./data/panama_papers.nodes.intermediary.csv')
officer = pd.read_csv('./data/panama_papers.nodes.officer.csv', low_memory=False)
other = pd.read_csv('./data/panama_papers.nodes.other.csv')

# %%
edges.head()
# Out:
#      node_1            rel_type    node_2     r.sourceID r.valid_until  \
# 0  10000035  registered_address  14095990  Panama Papers           NaN
# 1  10000044  registered_address  14091035  Panama Papers           NaN
# 2  10000055  registered_address  14095990  Panama Papers           NaN
# 3  10000064  registered_address  14091429  Panama Papers           NaN
# 4  10000089  registered_address  14098253  Panama Papers           NaN
#
#   r.start_date r.end_date
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN

# %%
address.head()
# Out:
#      labels(n)                                    n.valid_until  \
# 0  ["Address"]  The Panama Papers  data is current through 2015
# 1  ["Address"]  The Panama Papers  data is current through 2015
# 2  ["Address"]  The Panama Papers  data is current through 2015
# 3  ["Address"]  The Panama Papers  data is current through 2015
# 4  ["Address"]  The Panama Papers  data is current through 2015
#
#   n.country_codes     n.countries  n.node_id     n.sourceID  \
# 0             SGP       Singapore   14000001  Panama Papers
# 1             KAZ      Kazakhstan   14000002  Panama Papers
# 2             GBR  United Kingdom   14000003  Panama Papers
# 3             GGY        Guernsey   14000004  Panama Papers
# 4             KEN           Kenya   14000005  Panama Papers
#
#                                            n.address  n.name  \
# 0       -\t27 ROSEWOOD DRIVE #16-19 SINGAPORE 737920     NaN
# 1            "Almaly Village" v.5, Almaty Kazakhstan     NaN
# 2  "Cantonia" South Road St Georges Hill Weybridg...     NaN
# 3  "CAY-OS" NEW ROAD; ST.SAMPSON; GUERNSEY; CHANN...     NaN
# 4  "Chirag" Plot No 652; Mwamba Road; Kizingo; Mo...     NaN
#
#    n.jurisdiction_description  n.service_provider  n.jurisdiction  \
# 0                         NaN                 NaN             NaN
# 1                         NaN                 NaN             NaN
# 2                         NaN                 NaN             NaN
# 3                         NaN                 NaN             NaN
# 4                         NaN                 NaN             NaN
#
#    n.closed_date  n.incorporation_date  n.ibcRUC  n.type  n.status  \
# 0            NaN                   NaN       NaN     NaN       NaN
# 1            NaN                   NaN       NaN     NaN       NaN
# 2            NaN                   NaN       NaN     NaN       NaN
# 3            NaN                   NaN       NaN     NaN       NaN
# 4            NaN                   NaN       NaN     NaN       NaN
#
#    n.company_type  n.note
# 0             NaN     NaN
# 1             NaN     NaN
# 2             NaN     NaN
# 3             NaN     NaN
# 4             NaN     NaN

# %%
entity.head()
# Out:
#     labels(n)                                   n.valid_until n.country_codes  \
# 0  ["Entity"]  The Panama Papers data is current through 2015             HKG
# 1  ["Entity"]  The Panama Papers data is current through 2015             HKG
# 2  ["Entity"]  The Panama Papers data is current through 2015             HKG
# 3  ["Entity"]  The Panama Papers data is current through 2015             HKG
# 4  ["Entity"]  The Panama Papers data is current through 2015             HKG
#
#   n.countries  n.node_id     n.sourceID  \
# 0   Hong Kong   10000001  Panama Papers
# 1   Hong Kong   10000002  Panama Papers
# 2   Hong Kong   10000003  Panama Papers
# 3   Hong Kong   10000004  Panama Papers
# 4   Hong Kong   10000005  Panama Papers
#
#                                            n.address  \
# 0  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 1  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 2  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 3  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...
# 4  LOYAL PORT LIMITED 8/F; CRAWFORD TOWER 99 JERV...
#
#                                         n.name n.jurisdiction_description  \
# 0     TIANSHENG INDUSTRY AND TRADING CO., LTD.                      Samoa
# 1  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.                      Samoa
# 2                           HOTFOCUS CO., LTD.                      Samoa
# 3              SKY-BLUE GIFTS & TOYS CO., LTD.                      Samoa
# 4         FORTUNEMAKER INVESTMENTS CORPORATION                      Samoa
#
#   n.service_provider n.jurisdiction  n.closed_date n.incorporation_date  \
# 0    Mossack Fonseca            SAM            NaN          23-MAR-2006
# 1    Mossack Fonseca            SAM            NaN          27-MAR-2006
# 2    Mossack Fonseca            SAM            NaN          10-JAN-2006
# 3    Mossack Fonseca            SAM            NaN          06-JAN-2006
# 4    Mossack Fonseca            SAM            NaN          19-APR-2006
#
#   n.ibcRUC  n.type       n.status  n.company_type n.note
# 0    25221     NaN      Defaulted             NaN    NaN
# 1    25249     NaN      Defaulted             NaN    NaN
# 2    24138     NaN      Defaulted             NaN    NaN
# 3    24012     NaN      Defaulted             NaN    NaN
# 4   R25638     NaN  Changed agent             NaN    NaN

# %%
intermediary.head()
# Out:
#           labels(n)                                    n.valid_until  \
# 0  ["Intermediary"]  The Panama Papers  data is current through 2015
# 1  ["Intermediary"]  The Panama Papers  data is current through 2015
# 2  ["Intermediary"]  The Panama Papers  data is current through 2015
# 3  ["Intermediary"]  The Panama Papers  data is current through 2015
# 4  ["Intermediary"]  The Panama Papers  data is current through 2015
#
#   n.country_codes    n.countries  n.node_id     n.sourceID  \
# 0             ZAF   South Africa   11000001  Panama Papers
# 1             LIE  Liechtenstein   11000002  Panama Papers
# 2             MCO         Monaco   11000003  Panama Papers
# 3             BEL        Belgium   11000004  Panama Papers
# 4             LBN        Lebanon   11000005  Panama Papers
#
#                                            n.address  \
# 0  MICHAEL PAPAGEORGE; MR. 106 NICHOLSON STREET B...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        n.name  n.jurisdiction_description  n.service_provider  \
# 0     MICHAEL PAPAGEORGE, MR.                         NaN                 NaN
# 1          CORFIDUCIA ANSTALT                         NaN                 NaN
# 2               DAVID, RONALD                         NaN                 NaN
# 3  DE  BOUTSELIS, JEAN-PIERRE                         NaN                 NaN
# 4    THE LEVANT LAWYERS (TLL)                         NaN                 NaN
#
#    n.jurisdiction  n.closed_date  n.incorporation_date  n.ibcRUC  n.type  \
# 0             NaN            NaN                   NaN       NaN     NaN
# 1             NaN            NaN                   NaN       NaN     NaN
# 2             NaN            NaN                   NaN       NaN     NaN
# 3             NaN            NaN                   NaN       NaN     NaN
# 4             NaN            NaN                   NaN       NaN     NaN
#
#     n.status  n.company_type n.note
# 0     ACTIVE             NaN    NaN
# 1     ACTIVE             NaN    NaN
# 2  SUSPENDED             NaN    NaN
# 3  SUSPENDED             NaN    NaN
# 4     ACTIVE             NaN    NaN

# %%
officer.head()
# Out:
#      labels(n)                                   n.valid_until  \
# 0  ["Officer"]  The Panama Papers data is current through 2015
# 1  ["Officer"]  The Panama Papers data is current through 2015
# 2  ["Officer"]  The Panama Papers data is current through 2015
# 3  ["Officer"]  The Panama Papers data is current through 2015
# 4  ["Officer"]  The Panama Papers data is current through 2015
#
#   n.country_codes  n.countries  n.node_id     n.sourceID  n.address  \
# 0             KOR  South Korea   12000001  Panama Papers        NaN
# 1             CHN        China   12000002  Panama Papers        NaN
# 2             AUS    Australia   12000003  Panama Papers        NaN
# 3             JPN        Japan   12000004  Panama Papers        NaN
# 4             VNM     Viet Nam   12000005  Panama Papers        NaN
#
#                  n.name  n.jurisdiction_description  n.service_provider  \
# 0            KIM SOO IN                         NaN                 NaN
# 1             Tian Yuan                         NaN                 NaN
# 2  GREGORY JOHN SOLOMON                         NaN                 NaN
# 3        MATSUDA MASUMI                         NaN                 NaN
# 4           HO THUY NGA                         NaN                 NaN
#
#    n.jurisdiction  n.closed_date  n.incorporation_date  n.ibcRUC  n.type  \
# 0             NaN            NaN                   NaN       NaN     NaN
# 1             NaN            NaN                   NaN       NaN     NaN
# 2             NaN            NaN                   NaN       NaN     NaN
# 3             NaN            NaN                   NaN       NaN     NaN
# 4             NaN            NaN                   NaN       NaN     NaN
#
#    n.status  n.company_type n.note
# 0       NaN             NaN    NaN
# 1       NaN             NaN    NaN
# 2       NaN             NaN    NaN
# 3       NaN             NaN    NaN
# 4       NaN             NaN    NaN

# %%
other.head()
# Out:
# Empty DataFrame
# Columns: [labels(n), n.valid_until, n.country_codes, n.countries, n.node_id, n.sourceID, n.address, n.name, n.jurisdiction_description, n.service_provider, n.jurisdiction, n.closed_date, n.incorporation_date, n.ibcRUC, n.type, n.status, n.company_type, n.note]
# Index: []

# %%
officer['n.name'] = officer['n.name'].str.title()
byCountry = officer.groupby(['n.country_codes', 'n.countries'])['n.name'].nunique().to_frame().reset_index()
byCountry.columns = ['country_code', 'country_name', 'count']
byCountry
# Out:
#     country_code  country_name  count
# 0            ABW         Aruba     26
# 1            AGO        Angola     43
# 2            AIA      Anguilla    180
# 3            ALB       Albania     23
# 4            AND       Andorra     31
# ..           ...           ...    ...
# 196          WSM         Samoa    250
# 197          YEM         Yemen      8
# 198          ZAF  South Africa   1665
# 199          ZMB        Zambia     39
# 200          ZWE      Zimbabwe    246
#
# [201 rows x 3 columns]

# %%
world = gpd.read_file('./data/ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp')
world = world[['ADM0_A3', 'geometry']]
world.columns = ['country_code', 'geometry']
world = world[world['country_code'] != 'ATA']
world
# Out:
#     country_code                                           geometry
# 0            FJI  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1            TZA  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2            SAH  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3            CAN  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4            USA  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..           ...                                                ...
# 172          SRB  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 173          MNE  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 174          KOS  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 175          TTO  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 176          SDS  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
# [176 rows x 2 columns]

# %%
merged = world.merge(byCountry, how='left').fillna(0)
merged
# Out:
#     country_code                                           geometry  \
# 0            FJI  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1            TZA  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2            SAH  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3            CAN  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4            USA  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...
# ..           ...                                                ...
# 171          SRB  POLYGON ((18.82982 45.90887, 18.82984 45.90888...
# 172          MNE  POLYGON ((20.07070 42.58863, 19.80161 42.50009...
# 173          KOS  POLYGON ((20.59025 41.85541, 20.52295 42.21787...
# 174          TTO  POLYGON ((-61.68000 10.76000, -61.10500 10.890...
# 175          SDS  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...
#
#             country_name   count
# 0                   Fiji     3.0
# 1               Tanzania    41.0
# 2                      0     0.0
# 3                 Canada   707.0
# 4          United States  3288.0
# ..                   ...     ...
# 171               Serbia    28.0
# 172           Montenegro    17.0
# 173                    0     0.0
# 174  Trinidad and Tobago    16.0
# 175                    0     0.0
#
# [176 rows x 4 columns]

# %%
def add_color(row):
    if row['count'] >=10000:
        return 'firebrick'
    elif row['count'] >=2500:
        return 'indianred'
    elif row['count'] >= 2000:
        return 'lightcoral'
    elif row['count'] >= 1500:
        return 'darksalmon'
    elif row['count'] >= 1000:
        return 'lightsalmon'
    elif row['count'] >= 500:
        return 'navajowhite'
    else:
        return 'cornsilk'

merged['color'] = merged.apply(lambda row: add_color(row), axis=1)
ax = merged.plot(color=merged['color'], figsize = (14, 8))

# Create custom legend (Because there is no default way to do it)

color_dict = {
    '10,000>' : 'firebrick',
    '2,500-10,000' : 'indianred',
    '2,000-2,500' : 'lightcoral',
    '1,500-2,000' : 'darksalmon',
    '1,000-1,500' : 'lightsalmon',
    '500-1,000' : 'navajowhite',
    '>500' : 'cornsilk'
}

custom_points = [Line2D([0], [0], marker="o", linestyle="none", markersize=10, color=color) for color in color_dict.values()]
leg_points = ax.legend(custom_points, color_dict.keys(), loc=3)
ax.add_artist(leg_points)
ax.set_yticks([])
ax.set_xticks([])
for spine in ax.spines.values():
    spine.set_visible(False)
ax.set_title('Countries by the amount of officers mentioned in the Panama Papers');

# %%
perCountry = byCountry[['country_name', 'count']].sort_values(by=['count'], ascending=False).reset_index()
perCountry = perCountry.set_index('country_name').drop(columns=['index']).head(20)
# Will add a legend later
ax = perCountry.plot(kind='bar', figsize = (15, 4), legend=False)
ax.set_xlabel('')
ax.tick_params(axis="x", rotation=70, labelsize=12)
ax.set_title('Top 20 countries by amount of officers mentioned in the Panma Papers');
